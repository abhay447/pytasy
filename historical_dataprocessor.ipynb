# %%
# %%sh
# wget https://cricsheet.org/downloads/all_json.zip
# Out:
# --2023-02-07 23:32:28--  https://cricsheet.org/downloads/all_json.zip
# Resolving cricsheet.org (cricsheet.org)... 64.90.49.16
# Connecting to cricsheet.org (cricsheet.org)|64.90.49.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65652838 (63M) [application/zip]
# Saving to: ‘all_json.zip’
#
#      0K .......... .......... .......... .......... ..........  0% 89.9K 11m53s
#     50K .......... .......... .......... .......... ..........  0%  184K 8m50s
#    100K .......... .......... .......... .......... ..........  0% 33.5M 5m54s
#    150K .......... .......... .......... .......... ..........  0%  188K 5m50s
#    200K .......... .......... .......... .......... ..........  0% 12.6M 4m41s
#    250K .......... .......... .......... .......... ..........  0% 30.4M 3m54s
#    300K .......... .......... .......... .......... ..........  0% 32.4M 3m21s
#    350K .......... .......... .......... .......... ..........  0% 34.5M 2m56s
# ...

# %%
# %%sh
# unzip all_json.zip -d raw_historical_data
# Out:
# Archive:  all_json.zip
#   inflating: raw_historical_data/README.txt
#   inflating: raw_historical_data/1000851.json
#   inflating: raw_historical_data/1000853.json
#   inflating: raw_historical_data/1000855.json
#   inflating: raw_historical_data/1000881.json
#   inflating: raw_historical_data/1000883.json
#   inflating: raw_historical_data/1000885.json
#   inflating: raw_historical_data/1000887.json
#   inflating: raw_historical_data/1000889.json
#   inflating: raw_historical_data/1000891.json
#   inflating: raw_historical_data/1000893.json
#   inflating: raw_historical_data/1000895.json
#   inflating: raw_historical_data/1001349.json
#   inflating: raw_historical_data/1001351.json
#   inflating: raw_historical_data/1001353.json
#   inflating: raw_historical_data/1001371.json
#   inflating: raw_historical_data/1001373.json
#   inflating: raw_historical_data/1001375.json
#   inflating: raw_historical_data/1003271.json
#   inflating: raw_historical_data/1003273.json
# ...

# %%
from pyspark.sql import SparkSession

#Create SparkSession
spark = SparkSession.builder.appName('SparkByExamples.com').getOrCreate()
# Out:
# 23/02/07 23:43:11 WARN Utils: Your hostname, Chaturvedi_PC resolves to a loopback address: 127.0.1.1; using 172.24.74.240 instead (on interface eth0)
# 23/02/07 23:43:11 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 23/02/07 23:43:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
df = spark.read.json("raw_historical_data/1014845.json")

# %%
df.printSchema()
# Out:
# root
#  |-- _corrupt_record: string (nullable = true)
